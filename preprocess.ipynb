# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 52.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 26.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('correct_tiny_features.csv')
df
# Out:
#                                                     text  post_date  user_id  \
# 0      Я смеялся до слёз. Пародия про каникулы презид...       2020      856
# 1      Торт "Наполеон" на сковороде Готовится, быстро...       2020      856
# 2                                             Красотень!       2020      861
# 3      Продлить выплаты в 10000 тыс.рублей на детей д...       2020      861
# 4      Единовременная выплата 10000 на каждого ребенк...       2020      861
# ...                                                  ...        ...      ...
# 30226                                               Live       2019     7329
# 30227  Новости -Духовная семинария встретила праздник...       2019     7329
# 30228  Божественная литургия на греческом языке стала...       2019     7329
# 30229          очередной наш выпуск "ответ семинариста"😊       2019     7329
# 30230                                     С Новым Годом!       2019     7329
#
# ...

# %%
health = pd.read_csv('health.csv')
health
# Out:
#         ID  эмоциональное благополучие sum  социальное благополучие sum  \
# 0      846                               6                           10
# 1      851                              12                           19
# 2      856                              11                            4
# 3      859                               9                           15
# 4      861                               8                            2
# ...    ...                             ...                          ...
# 1376  7227                              11                           20
# 1377  7234                              12                           14
# 1378  7240                               9                           13
# 1379  7253                               9                           17
# 1380  7303                              13                           14
#
#       психологическое благополучие sum  психологическое здоровье sum  \
# ...

# %%
health['user_id'] = health['ID']

# %%
health['soc'] = health['социальное благополучие mean']
health['emo'] = health['эмоциональное благополучие mean']
health['psych'] = health['психологическое благополучие mean']
health['health'] = health['психологическое здоровье mean']

# %%
health2 = health[health.user_id.isin(df.user_id.unique())]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Укажите названия колонок
columns = ['health', 'soc', 'emo', 'psych']

# Создайте сетку графиков
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
axes = axes.flatten()

# Проход по каждой колонке и создание графика
for i, column in enumerate(columns):
    # Распределение
    sns.histplot(data=health2, x=column, kde=True, ax=axes[i])
    if column == 'health':
      axes[i].set_title(f'Распределение психологическое здоровье')
    if column == 'soc':
      axes[i].set_title(f'Распределение социальное благополучие')
    if column == 'emo':
      axes[i].set_title(f'Распределение эмоциональное благополучие')
    if column == 'psych':
      axes[i].set_title(f'Распределение психологическое благополучие')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Частота')

    # Среднее значение и стандартное отклонение
    mean_val = df[column].mean()
    std_val = df[column].std()
    axes[i].axvline(mean_val, color='red', linestyle='--', label='Среднее')
    axes[i].axvline(mean_val + std_val, color='green', linestyle='--', label='Среднее ± Стд отклонение')
    axes[i].axvline(mean_val - std_val, color='green', linestyle='--')
    axes[i].legend()

# Отобразите графики
plt.tight_layout()
plt.show()
